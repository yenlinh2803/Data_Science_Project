# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_train = pd.read_csv("/Users/yenlinh/Documents/GitHub/Data_Science_Project/Titanic/raw_data/train.csv")
data_train.head()
data_test = pd.read_csv("/Users/yenlinh/Documents/GitHub/Data_Science_Project/Titanic/raw_data/test.csv")
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data1 = data_train.copy(deep=True)
data1_value = data_test.copy(deep=True)
dataset_list = [data1,data1_value]

# %%
print('Number unique value of columns data Train :',data1.nunique())
print('Number unique value of columns data Test :',data1_value.nunique())
# Out:
# Number unique value of columns data Train : PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64
# Number unique value of columns data Test : PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
print(data1.describe())
print("-"*10)
print(data1.info())
print("-"*10)
print('NUll: ',data1.isna().sum())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# ----------
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
print(data1_value.describe())
print("-"*10)
print(data1_value.info())
print("-"*10)
print(data1_value.isna().sum())
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200
# ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# ...

# %%
for dataset in dataset_list:
    dataset['Age'].fillna(dataset['Age'].median(), inplace = True)
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace = True)
    dataset['Age'].fillna(dataset['Fare'].median(), inplace = True)

column_drop=['PassengerId','Cabin','Ticket']

# %%
data1.drop(column_drop, axis = 1, inplace= True)

# %%
data1.head(20)
print(data1.isnull().sum())
print('-'*10)
print(data1_value.isnull().sum())
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
# ----------
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
for dataset in dataset_list:
    dataset['FamilySize'] = dataset ['SibSp'] + dataset['Parch'] + 1
    dataset['IsAlone']=1
    dataset['IsAlone'].loc[dataset['FamilySize']>1]=0
    dataset['Title']= dataset['Name'].str.split(", ", expand=True)[1].str.split(". ",expand=True)[0]
    dataset['FareBin']= pd.qcut(dataset['Fare'],4)
    dataset['AgeBin']= pd.cut(dataset['Age'].astype(int),5)
# Out:
# /Users/yenlinh/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/yenlinh/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data1['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Lady          1
# Don           1
# Ms            1
# Mme           1
# Jonkheer      1
# th            1
# Sir           1
# Capt          1
# Name: Title, dtype: int64

# %%
temp=data1

# %%
temp['Title']= temp['Name'].str.split(", ", expand=True)[1].str.split(". ",expand=True)[0]
temp['FareBin']= pd.qcut(temp['Fare'],4)
temp['AgeBin']= pd.cut(temp['Age'].astype(int),5)
print(temp['AgeBin'].head())
temp.head()
# Out:
# 0    (16.0, 32.0]
# 1    (32.0, 48.0]
# 2    (16.0, 32.0]
# 3    (32.0, 48.0]
# 4    (32.0, 48.0]
# Name: AgeBin, dtype: category
# Categories (5, interval[float64]): [(-0.08, 16.0] < (16.0, 32.0] < (32.0, 48.0] < (48.0, 64.0] < (64.0, 80.0]]
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  IsAlone Title  \
# 0    male  22.0      1      0   7.2500        S           2        0    Mr
# 1  female  38.0      1      0  71.2833        C           2        0   Mrs
# 2  female  26.0      0      0   7.9250        S           1        1  Miss
# ...

# %%
temp['AgeBin'].value_counts()
#print(type(temp['AgeBin']))
# Out:
# (16.0, 32.0]     525
# (32.0, 48.0]     186
# (-0.08, 16.0]    100
# (48.0, 64.0]      69
# (64.0, 80.0]      11
# Name: AgeBin, dtype: int64

# %%
data1.loc[data1['Age']<1]
# Out:
#      Survived  Pclass                             Name     Sex   Age  SibSp  \
# 78          1       2    Caldwell, Master. Alden Gates    male  0.83      0
# 305         1       1   Allison, Master. Hudson Trevor    male  0.92      1
# 469         1       3    Baclini, Miss. Helene Barbara  female  0.75      2
# 644         1       3           Baclini, Miss. Eugenie  female  0.75      2
# 755         1       2        Hamalainen, Master. Viljo    male  0.67      1
# 803         1       3  Thomas, Master. Assad Alexander    male  0.42      0
# 831         1       2  Richards, Master. George Sibley    male  0.83      1
#
#      Parch      Fare Embarked  FamilySize  IsAlone   Title          FareBin  \
# 78       2   29.0000        S           3        0  Master   (14.454, 31.0]
# 305      2  151.5500        S           4        0  Master  (31.0, 512.329]
# 469      1   19.2583        C           4        0    Miss   (14.454, 31.0]
# ...
