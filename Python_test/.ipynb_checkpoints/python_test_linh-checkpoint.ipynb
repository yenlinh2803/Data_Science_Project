# %%
import pandas as pd
import numpy as np
import datetime

# %%
t0 = datetime.datetime.now()
data = pd.read_excel ("Test_Pandas.xlsx")
t1 = datetime.datetime.now()
print('Execution time: {}'.format(t1 - t0))
data.head()
# Out:
# Execution time: 0:00:59.830639
#      itemid  shopid                     item_name  \
# 0   1925574  210000         Golden mobile numbers
# 1   1925617  210000         Golden mobile numbers
# 2    943600  210000         Golden Mobile Numbers
# 3   1064405  210000         Golden Mobile Numbers
# 4  20046620  760000  101% AUTHENTIC BASEBALL CAPS
#
#                                     item_description  \
# 0  Unregistered prepaid cards1) 93355333  selling...
# 1  Unregistered prepaid cards1) 93355888  selling...
# 2  Unregistered prepaid cards. Can port to post p...
# 3  Unregistered prepaid cards. Can port to post p...
# 4  PREORDER Takes about 23 weeks to arrive, will ...
#
#                                       item_variation  price  stock  \
# 0                                                 {}  400.0      1
# 1                                                 {}  400.0      1
# 2                                                 {}    8.0      1
# 3                                                 {}    8.0      1
# 4  {NEWERA BLACK: 35.0, NIKE SWOOSH DENIM: 35.0, ...   35.0    300
#
#            category  cb_option  is_preferred  sold_count  item_creation_date
# 0  Mobile & Gadgets          0             0           0 2015-10-01 00:24:42
# 1  Mobile & Gadgets          0             0           0 2015-10-01 00:26:37
# 2  Mobile & Gadgets          0             0           0 2015-08-25 21:02:13
# 3  Mobile & Gadgets          0             0           0 2015-08-30 20:16:07
# 4   Women's Apparel          0             0           0 2016-05-09 01:14:34

# %%
'''
Itemid  - a unique ID of the product
Shopid - a unique ID of the shop
item_name - product title  
item_description - detailed  product description
item_variation - stores variations of a product (e.g. different colours or sizes, in the format like {variation 1 name: variation 1 price, variation 2 name: variation 2 price})
price - how much does the item sold
stock - how many stocks left 
category - which category does the product belongs to 
cb_option - 1 indicates the product is sold by a cross border shop
is_preferred - 1 indicates the product is sold by a preferred shop
sold_count - how many products have been sold 
item_creation_date - when are the product uploaded by the seller
'''

# %%
raw_data = data
#Assign all column names to a variable named “columns”
columns = raw_data.columns
print(columns)
# Out:
# Index(['itemid', 'shopid', 'item_name', 'item_description', 'item_variation',
#        'price', 'stock', 'category', 'cb_option', 'is_preferred', 'sold_count',
#        'item_creation_date'],
#       dtype='object')

# %%
#How many unique shops are in the dataset?
nb_shop = raw_data['shopid'].nunique()
print('unique shops are in the dataset=',nb_shop)

#How many unique preferred and cross border shops are in the dataset?
nb_shop_pre_cb = raw_data.loc[(raw_data['cb_option']==1) & (raw_data['is_preferred']==1),:]
nb_shop_pre_cb = nb_shop_pre_cb['shopid'].nunique()
print('unique preferred and cross border shops are in the dataset= ',nb_shop_pre_cb)

#How many products have zero sold count?
nb_product_sold = raw_data.loc[raw_data['sold_count']==0,:]
nb_product_sold.head()
nb_product_sold = nb_product_sold['itemid'].nunique()
print('products have zero sold count=',nb_product_sold)

#How many products were created in the year 2018?
nb_product_2018 = raw_data.loc[(raw_data['item_creation_date'] >= '2018-01-01 00:00:00') & (raw_data['item_creation_date'] < '2019-01-01 00:00:00'),:]
print('Number products were created in the year 2018= ',nb_product_2018['itemid'].nunique())
print('Check min date of column creation date=',nb_product_2018['item_creation_date'].min())
print('Check max date of column creation date=',nb_product_2018['item_creation_date'].max())
# Out:
# unique shops are in the dataset= 7856
# unique preferred and cross border shops are in the dataset=  158
# products have zero sold count= 438092
# Number products were created in the year 2018=  177407
# Check min date of column creation date= 2018-01-01 02:01:09
# Check max date of column creation date= 2018-04-09 03:01:01

# %%
#Top 3 Preferred shops’ shopid that have the largest number of unique products
top_3_pre = raw_data.loc[(raw_data['is_preferred']==1),:]
top_3_pre = top_3_pre.groupby('shopid')['itemid'].nunique()
top_3_pre = pd.DataFrame(top_3_pre)
top_3_pre = top_3_pre.reset_index()
top_3_pre.sort_values(["itemid"], axis=0, ascending=False, inplace=True, na_position ='last')
top_3_pre = top_3_pre.rename(columns = {'itemid':'nb_unique_products'})
print('shopid that have the largest number of unique products:\n',top_3_pre.iloc[0:3,])

#Top 3 Categories that have the largest number of unique cross-border products
top_3_cat_cb = raw_data.loc[(raw_data['cb_option']==1),:]
top_3_cat_cb = top_3_cat_cb.groupby('category')['itemid'].nunique()
top_3_cat_cb = pd.DataFrame(top_3_cat_cb)
top_3_cat_cb = top_3_cat_cb.reset_index()
top_3_cat_cb.sort_values(by=['itemid'], axis=0, ascending = False, inplace = True, na_position = 'last')
top_3_cat_cb = top_3_cat_cb.rename(columns = {'itemid':'nb_unique_products'})
print('Top 3 Categories that have the largest number of unique cross-border products:\n',top_3_cat_cb.iloc[0:3,:])
# Out:
# shopid that have the largest number of unique products:
#         shopid  nb_unique_products
# 481  43384791                2034
# 156   6072241                1998
# 365  26974701                1037
# Top 3 Categories that have the largest number of unique cross-border products:
#              category  nb_unique_products
# 17   Women's Apparel               80494
# 12  Mobile & Gadgets               58760
# 10        Men's Wear               51795

# %%
#Find Top 3 shopid with the highest revenue (Assumption: the product price has not been changed.) 
top_3_revenue = raw_data
top_3_revenue['revenue'] = top_3_revenue['price'] * top_3_revenue['sold_count']
top_3_revenue = top_3_revenue.groupby('shopid')['revenue'].sum()
top_3_revenue= pd.DataFrame(top_3_revenue)
top_3_revenue = top_3_revenue.reset_index()
top_3_revenue.sort_values(by = ['revenue'],axis=0, ascending = False, inplace = True, na_position='last')
print('Top 3 shopid with the highest revenue: \n',top_3_revenue.iloc[0:3,])
# Out:
# Top 3 shopid with the highest revenue:
#          shopid    revenue
# 4842  18796234  177897.79
# 6042  30769353   63491.39
# 6027  30628794   39852.00

# %%
#Find number of products that have more than 3 variations (do not include products with 3 or fewer variations)
raw_data['item_variation'].keys()
# Out:
# RangeIndex(start=0, stop=464433, step=1)

# %%
#Use pandas function to identify duplicated listings within each shop (If listing A and B in shop S have the exactly same product title, product detailed description, and price, both listing A and B are considered as duplicated listings)
#Mark those duplicated listings with True otherwise False and store the marking result in a new column named “is_duplicated” 
shop_duplicate = raw_data[raw_data.duplicated(['shopid','item_name','item_description','price'])]
new_df['is_duplicated'] = 

df[df.countries.isin(countries)]
#Find duplicate listings that has less than 2 sold count and store the result in a new excel file named “duplicated_listings.xlsx”



#Find the preferred shop shopid that have the most number of duplicated listings
# Out:
#             itemid    shopid  \
# 9        809446063  49082000
# 24       868298757  53609000
# 26       868421248  53609000
# 29       864812407  53609000
# 31       874066799  53609000
# 35       868609496  53609000
# 37       868526863  53609000
# 39       874033786  53609000
# 45       868402016  53609000
# 48       868564173  53609000
# 50       868597991  53609000
# 52       868442545  53609000
# 67        78723069   5844001
# 77      1041743233  61803002
# 81      1040486882  61803002
# 83      1032386619  61803002
# 84      1032402288  61803002
# 87      1033905361  61803002
# 90      1034003228  61803002
# 93      1040390159  61803002
# 95      1040398754  61803002
# 97      1032386383  61803002
# 98      1032401972  61803002
# 101     1033906304  61803002
# 104     1034003604  61803002
# 111     1033907134  61803002
# 120     1040415050  61803002
# 122     1040558202  61803002
# 126     1040507253  61803002
# 128     1041818029  61803002
# ...            ...       ...
# 464331   949469495  29564999
# 464332   949507985  29564999
# 464333   951242702  29564999
# 464334   953382733  29564999
# 464335   953459413  29564999
# 464336   953514680  29564999
# 464337   953537440  29564999
# 464339   953335660  29564999
# 464341   942586435  29564999
# 464342   942617741  29564999
# 464346   944294819  29564999
# 464347   945839781  29564999
# 464349   948386858  29564999
# 464350   948416979  29564999
# 464356   943686509  29564999
# 464358   943772426  29564999
# 464369   964427394  29564999
# 464373   953175753  29564999
# 464375   948620553  29564999
# 464378   949299810  29564999
# 464380   951281867  29564999
# 464382   953290574  29564999
# 464383   953437359  29564999
# 464384   953571523  29564999
# 464385   953930077  29564999
# 464389   951624585  29564999
# 464395   229344425  20242999
# 464397   244575108  20242999
# 464418   502347297  13744999
# 464424   314601343  13744999
#
#                                                 item_name  \
# 9       Women Lace Bra Bustier Crop Tops Soft Mesh Tri...
# 24      Original New Arrival Adidas Authentic 2017 Yea...
# 26      Original New Arrival Official Adidas Originals...
# 29      Intersport New Arrival Authentic Converse Clas...
# 31      New Arrival Official Adidas Originals EQT SUPP...
# 35      New Arrival Authentic Adidas Originals TUBULAR...
# 37      Original New Arrival Official Adidas Energy Bo...
# 39      Original New Arrival Authentic Adidas Mens Boo...
# 45      New Arrival Authentic Adidas Originals SUPERST...
# 48      Original New Arrival Official Adidas Originals...
# 50      Original New Arrival Official Adidas STAN SMIT...
# 52      Original New Arrival Official Adidas Originals...
# 67                                   Nopierce Septum Ring
# 77      Apple iPhone8 8Plus Glass Phone Case Cartoon T...
# 81      VIVO X9 X9 plus Mobile Phone Glass Tempered Fi...
# 83      Apple iPad2 iPad3 iPad 4 Flat Leather Case Pro...
# 84      Apple iPad2 iPad3 iPad 4 Flat Leather Case Pro...
# 87      Apple iPad2 iPad3 iPad 4 Flat Leather Case Pro...
# 90      Apple iPad2 iPad3 iPad 4 Flat Leather Case Pro...
# 93      OPPO R9s R9splus Mobile Phone Glass Tempered F...
# 95      OPPO R11 R11plus Mobile Phone Glass Tempered F...
# 97      Apple NEW iPad mini 2 3 4 Flat Leather Case Pr...
# 98      Apple NEW iPad mini 2 3 4 Flat Leather Case Pr...
# 101     Apple iPad mini 2 3 4 Flat Leather Case Protec...
# 104     Apple iPad mini 2 3 4 Flat Leather Case Protec...
# 111     Apple iPad Pro 9.7 2016 Flat Leather Case Prot...
# 120     OPPO R11s Mobile Phone Glass Tempered Film R11...
# 122     iPhone 6s plus Mobile Phone Glass Tempered Fil...
# 126     VIVO X9S X9S plus Mobile Phone Glass Tempered ...
# 128     VIVO X9 X20 Glass Phone Case Cartoon Tough Cas...
# ...                                                   ...
# 464331                                【MXL】Letter TShirts
# 464332                                【MXL】Letter TShirts
# 464333                                【MXL】Letter TShirts
# 464334                                【MXL】Letter TShirts
# 464335                                【MXL】Letter TShirts
# 464336                                【MXL】Letter TShirts
# 464337                                【MXL】Letter TShirts
# 464339                           【MXL】Printed Long sleeve
# 464341                   【SXL】Student Short Sleeve Tshirt
# 464342                   【SXL】Student Short Sleeve Tshirt
# 464346                        【SXL】Letter Printing Tshirt
# 464347                        【SXL】Letter Printing Tshirt
# 464349                                       【MXL】TShirts
# 464350                                       【MXL】TShirts
# 464356                           【SXL】Short Sleeve Tshirt
# 464358                       【SXL】Embroidered Rose Tshirt
# 464369                             【SXL】Broken Hole Jeans
# 464373                           【MXL】Long Sleeve Tshirts
# 464375                    【MXL】Tshirts with short sleeves
# 464378                    【MXL】Tshirts with short sleeves
# 464380                    【MXL】Tshirts with short sleeves
# 464382                    【MXL】Tshirts with short sleeves
# 464383                    【MXL】Tshirts with short sleeves
# 464384                    【MXL】Tshirts with short sleeves
# 464385                    【MXL】Tshirts with short sleeves
# 464389                               【MXL】Striped Tshirts
# 464395  10Pcs Makeup Foundation Eye Shadow Powder Eyel...
# 464397  10pcs Pro Eyeshadow  Eyeliner Foundation Makeu...
# 464418              Women Sexy Bandage Push Up Bikini Set
# 464424       Cute Flower Sleeveless Mesh Baby Girls Dress
#
#                                          item_description  \
# 9       Material: Terylene Colors: BalckStyle: Sexy Br...
# 24      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 26      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 29      •\tBrand Name:CONVERSE•\tDepartment Name:Adult...
# 31      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 35      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 37      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 39      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 45      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 48      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 50      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 52      •\tBrand Name:Adidas•\tDepartment Name:Adult•\...
# 67      High quality septum ring  Available in silver,...
# 77      Please pay attention before placing orders! ! ...
# 81      Please pay attention before placing orders! ! ...
# 83      The holster of iPad about cartoon seriesThe ma...
# 84      The holster of iPad about cartoon seriesThe ma...
# 87      The holster of iPad about cartoon seriesThe ma...
# 90      The holster of iPad about cartoon seriesThe ma...
# 93      Please pay attention before placing orders! ! ...
# 95      Please pay attention before placing orders! ! ...
# 97      The holster of iPad about cartoon seriesThe ma...
# 98      The holster of iPad about cartoon seriesThe ma...
# 101     The holster of iPad about cartoon seriesThe ma...
# 104     The holster of iPad about cartoon seriesThe ma...
# 111     The holster of iPad about cartoon seriesThe ma...
# 120     Please pay attention before placing orders! ! ...
# 122     Please pay attention before placing orders! ! ...
# 126     Please pay attention before placing orders! ! ...
# 128     Please pay attention before placing orders! ! ...
# ...                                                   ...
# 464331  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464332  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464333  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464334  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464335  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464336  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464337  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464339  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464341  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464342  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464346  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464347  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464349  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464350  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464356  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464358  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464369  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464373  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464375  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464378  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464380  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464382  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464383  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464384  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464385  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464389  HI, WELCOME to hereSize: S=40KG, M=4045KG, L=4...
# 464395  Handle material:WoodBrush material:Nylon#Brush...
# 464397  Material: Plastic tube, nylon hair#Brush #make...
# 464418  1.Main Fabric:82%Nylon,18%Lycra,200220GSM2.Twi...
# 464424  Style: Cute Material: Cotton Fabric Type: Broa...
#
#                                            item_variation   price  stock  \
# 9                             {S: 9.98, M: 9.98, L: 9.98}    9.98    300
# 24      {US5.5: 158.0, US7: 158.0, US6: 158.0, US7.5: ...  158.00    108
# 26      {US8.5: 218.0, US10: 218.0, US7: 218.0, US7.5:...  218.00    144
# 29      {us5.5: 118.0, us9: 118.0, us4.5: 118.0, us10:...  118.00    195
# 31      {US8.5: 218.0, US10: 218.0, US7: 218.0, US7.5:...  218.00    147
# 35      {US5.5: 218.0, US7: 218.0, US6: 218.0, US5: 21...  218.00    114
# 37      {US8.5: 228.0, US10: 228.0, US7: 228.0, US7.5:...  228.00    152
# 39      {US8.5: 208.0, US10: 208.0, US7.5: 208.0, US10...  208.00    196
# 45      {US5.5: 118.0, US9: 118.0, US4.5: 118.0, US10:...  118.00    234
# 48      {US5.5: 238.0, US9: 238.0, US4.5: 238.0, US10:...  238.00    228
# 50      {US8.5: 198.0, US10: 198.0, US7: 198.0, US7.5:...  198.00    200
# 52      {US10: 208.0, US7: 208.0, US8.5: 208.0, US6.5:...  208.00    152
# 67               {Rose Gold: 6.0, Silver: 6.0, Gold: 6.0}    6.00      6
# 77      {I8 5.5 NO.3: 14.93, I8 5.5 NO.2: 14.93, I8 5....   14.93   1000
# 81      {X9 NO.6: 8.45, X9 NO.5: 8.45, X9 NO.4: 8.45, ...    8.45   1200
# 83                           {brown: 23.92, white: 23.92}   23.92    200
# 84                             {black: 23.92, red: 23.92}   23.92    200
# 87      {No.4: 23.92, No.3: 23.92, No.2: 23.92, No.1: ...   23.92    400
# 90                            {Pink: 23.92, black: 23.92}   23.92    200
# 93      {R9S NO.1: 8.45, R9S NO.3: 8.45, R9S NO.2: 8.4...    8.45   1200
# 95      {R11plus NO.3: 8.45, R11 NO.6: 8.45, R11 NO.5:...    8.45   1200
# 97      {mini123 white: 23.92, mini123 brown: 23.92, m...   23.92    400
# 98      {mini4 black: 23.92, mini123 black: 23.92, min...   23.92    400
# 101     {mini4 No.1: 23.92, mini4 No.2: 23.92, mini4 N...   23.92    800
# 104     {mini4 Pink: 23.92, mini123 black: 23.92, mini...   23.92    400
# 111     {No.4: 23.92, No.3: 23.92, No.2: 23.92, No.1: ...   23.92    400
# 120     {NO.6: 8.45, NO.5: 8.45, NO.4: 8.45, NO.3: 8.4...    8.45    600
# 122     {i6 4.7 NO.1: 8.45, i6 4.7 NO.2: 8.45, i6 4.7 ...    8.45   1400
# 126     {X9S plus NO.6: 8.45, X9S plus NO.7: 8.45, X9S...    8.45   1400
# 128     {X9 NO.5: 14.93, X9 NO.4: 14.93, X9 NO.3: 14.9...   14.93   1000
# ...                                                   ...     ...    ...
# 464331  {While【L】: 8.22, Black【XL】: 8.22, While【M】: 8....    8.22    300
# 464332  {While【L】: 8.22, Black【XL】: 8.22, While【M】: 8....    8.22    300
# 464333     {While【L】: 7.8, While【XL】: 7.8, While【M】: 7.8}    7.80    150
# 464334  {While【L】: 8.22, Black【XL】: 8.22, While【M】: 8....    8.22    300
# 464335  {While【L】: 8.22, Black【XL】: 8.22, While【M】: 8....    8.22    300
# 464336     {While【L】: 7.8, While【XL】: 7.8, While【M】: 7.8}    7.80    150
# 464337     {While【L】: 7.8, While【XL】: 7.8, While【M】: 7.8}    7.80    150
# 464339  {While【L】: 8.22, While【XL】: 8.22, While【M】: 8.22}    8.22    150
# 464341  {Pink【XL】: 4.84, Pink【S】: 4.84, Red【S】: 4.84, ...    4.84    400
# 464342  {White【S】: 4.84, White【M】: 4.84, White【XL】: 4....    4.84    400
# 464346  {White【L】: 4.84, White【XL】: 4.84, White【S】: 4....    4.84    200
# 464347  {Black 【S】: 4.84, White【S】: 4.84, White【M】: 4....    4.84    400
# 464349  {While【L】: 7.8, Black【XL】: 7.8, While【M】: 7.8,...    7.80    300
# 464350  {While【L】: 7.8, Black【XL】: 7.8, While【M】: 7.8,...    7.80    300
# 464356  {Pink【XL】: 4.84, Pink【S】: 4.84, White【S】: 4.84...    4.84    400
# 464358  {White【S】: 4.84, White【M】: 4.84, White【XL】: 4....    4.84    400
# 464369  {Picture color【S】: 10.4, Picture color【M】: 10....   10.40    200
# 464373  {While【L】: 8.22, While【XL】: 8.22, While【M】: 8.22}    8.22    150
# 464375  {While【L】: 8.22, While【XL】: 8.22, While【M】: 8.22}    8.22    150
# 464378  {While【L】: 8.22, While【XL】: 8.22, While【M】: 8.22}    8.22    150
# 464380  {While【L】: 7.8, Black【XL】: 7.8, While【M】: 7.8,...    7.80    300
# 464382  {While【L】: 8.22, While【XL】: 8.22, While【M】: 8.22}    8.22    150
# 464383  {While【L】: 7.8, Black【XL】: 7.8, While【M】: 7.8,...    7.80    300
# 464384  {While【L】: 9.06, While【XL】: 9.06, While【M】: 9.06}    9.06    150
# 464385  {While【L】: 7.8, Black【XL】: 7.8, While【M】: 7.8,...    7.80    300
# 464389  {Black【XL】: 7.8, Black【M】: 7.8, Black【L】: 7.8,...    7.80    300
# 464395                                                 {}    6.36    100
# 464397                                                 {}   12.48    100
# 464418                  {S: 9.0, M: 9.0, L: 9.0, XL: 9.0}    9.00      0
# 464424  {9 Month: 7.57, 12 Month: 7.57, 24 Month: 7.57...    7.57      0
#
#                        category  cb_option  is_preferred  sold_count  \
# 9               Women's Apparel          1             0           0
# 24                Women's Shoes          1             0           0
# 26                  Men's Shoes          1             0           0
# 29                  Men's Shoes          1             0           0
# 31                  Men's Shoes          1             0           0
# 35                Women's Shoes          1             0           0
# 37                  Men's Shoes          1             0           0
# 39                  Men's Shoes          1             0           0
# 45                  Men's Shoes          1             0           0
# 48                  Men's Shoes          1             0           0
# 50                  Men's Shoes          1             0           0
# 52                  Men's Shoes          1             0           0
# 67      Jewellery & Accessories          0             0           0
# 77             Mobile & Gadgets          1             0           0
# 81             Mobile & Gadgets          1             0           0
# 83             Mobile & Gadgets          1             0           0
# 84             Mobile & Gadgets          1             0           0
# 87             Mobile & Gadgets          1             0           0
# 90             Mobile & Gadgets          1             0           0
# 93             Mobile & Gadgets          1             0           0
# 95             Mobile & Gadgets          1             0           0
# 97             Mobile & Gadgets          1             0           0
# 98             Mobile & Gadgets          1             0           0
# 101            Mobile & Gadgets          1             0           0
# 104            Mobile & Gadgets          1             0           0
# 111            Mobile & Gadgets          1             0           0
# 120            Mobile & Gadgets          1             0           0
# 122            Mobile & Gadgets          1             0           0
# 126            Mobile & Gadgets          1             0           0
# 128            Mobile & Gadgets          1             0           0
# ...                         ...        ...           ...         ...
# 464331          Women's Apparel          1             0           0
# 464332          Women's Apparel          1             0           0
# 464333          Women's Apparel          1             0           0
# 464334          Women's Apparel          1             0           0
# 464335          Women's Apparel          1             0           0
# 464336          Women's Apparel          1             0           0
# 464337          Women's Apparel          1             0           0
# 464339          Women's Apparel          1             0           0
# 464341          Women's Apparel          1             0           0
# 464342          Women's Apparel          1             0           0
# 464346          Women's Apparel          1             0           0
# 464347          Women's Apparel          1             0           0
# 464349          Women's Apparel          1             0           0
# 464350          Women's Apparel          1             0           0
# 464356          Women's Apparel          1             0           0
# 464358          Women's Apparel          1             0           0
# 464369          Women's Apparel          1             0           0
# 464373          Women's Apparel          1             0           0
# 464375          Women's Apparel          1             0           0
# 464378          Women's Apparel          1             0           0
# 464380          Women's Apparel          1             0           0
# 464382          Women's Apparel          1             0           0
# 464383          Women's Apparel          1             0           0
# 464384          Women's Apparel          1             0           0
# 464385          Women's Apparel          1             0           0
# 464389          Women's Apparel          1             0           0
# 464395          Health & Beauty          1             0           0
# 464397          Health & Beauty          1             0           0
# 464418          Women's Apparel          1             0           0
# 464424      Toys, Kids & Babies          1             0           0
#
#         item_creation_date  revenue
# 9      2018-01-05 16:08:24      0.0
# 24     2018-01-26 14:53:10      0.0
# 26     2018-01-26 15:31:46      0.0
# 29     2018-01-25 14:15:18      0.0
# 31     2018-01-28 14:08:38      0.0
# 35     2018-01-26 16:30:38      0.0
# 37     2018-01-26 16:04:16      0.0
# 39     2018-01-28 13:51:35      0.0
# 45     2018-01-26 15:25:53      0.0
# 48     2018-01-26 16:16:25      0.0
# 50     2018-01-26 16:27:01      0.0
# 52     2018-01-26 15:38:14      0.0
# 67     2016-10-20 22:15:45      0.0
# 77     2018-04-04 10:43:19      0.0
# 81     2018-04-03 20:25:31      0.0
# 83     2018-03-31 21:02:31      0.0
# 84     2018-03-31 21:08:26      0.0
# 87     2018-04-01 13:06:35      0.0
# 90     2018-04-01 13:53:04      0.0
# 93     2018-04-03 19:42:06      0.0
# 95     2018-04-03 19:46:10      0.0
# 97     2018-03-31 21:02:24      0.0
# 98     2018-03-31 21:08:17      0.0
# 101    2018-04-01 13:06:56      0.0
# 104    2018-04-01 13:53:13      0.0
# 111    2018-04-01 13:07:14      0.0
# 120    2018-04-03 19:53:28      0.0
# 122    2018-04-03 20:56:17      0.0
# 126    2018-04-03 20:34:35      0.0
# 128    2018-04-04 11:14:18      0.0
# ...                    ...      ...
# 464331 2018-02-28 22:07:05      0.0
# 464332 2018-02-28 22:26:12      0.0
# 464333 2018-03-01 17:18:07      0.0
# 464334 2018-03-02 17:28:21      0.0
# 464335 2018-03-02 18:02:35      0.0
# 464336 2018-03-02 18:28:44      0.0
# 464337 2018-03-02 18:39:21      0.0
# 464339 2018-03-02 17:06:48      0.0
# 464341 2018-02-25 21:12:30      0.0
# 464342 2018-02-25 21:33:42      0.0
# 464346 2018-02-26 18:21:35      0.0
# 464347 2018-02-27 12:20:06      0.0
# 464349 2018-02-28 13:58:48      0.0
# 464350 2018-02-28 14:12:24      0.0
# 464356 2018-02-26 13:52:50      0.0
# 464358 2018-02-26 14:38:48      0.0
# 464369 2018-03-07 13:26:12      0.0
# 464373 2018-03-02 15:42:56      0.0
# 464375 2018-02-28 15:32:50      0.0
# 464378 2018-02-28 20:36:39      0.0
# 464380 2018-03-01 17:35:22      0.0
# 464382 2018-03-02 16:45:10      0.0
# 464383 2018-03-02 17:52:31      0.0
# 464384 2018-03-02 18:55:40      0.0
# 464385 2018-03-02 21:54:49      0.0
# 464389 2018-03-01 20:51:00      0.0
# 464395 2017-04-22 02:00:29      0.0
# 464397 2017-05-04 00:43:36      0.0
# 464418 2017-09-19 16:27:45      0.0
# 464424 2017-06-20 23:06:49      0.0
#
# [194945 rows x 13 columns]
